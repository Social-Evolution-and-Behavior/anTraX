# %% [markdown]
# # Working with trajectory data

# %% [markdown]
# This notebook shows some examples to loading and working with anTraX results in python. The notebook can be dowloaded from []().

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from antrax import *
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
idx = pd.IndexSlice

# %% [markdown]
# ### Load data from tracked experiment
#
# We will use data from dataset J16. Replace the path to correct path on your system. By default, data from all IDs ('ants') and all movies will be loaded, but it can be changed using the arguments.

# %%
expdir = '/Users/asaf/Box Sync/anTraX/datasets/J16'
ex = axExperiment(expdir, session='antrax')
ad = axAntData(ex, movlist=[1], antlist=['GO','PP'])

# %% [markdown]
# The data is loaded into the antdata object, and is stored in the pandas table antdata.data. By default, the values of the xy coordinates and the orientation angle are loaded:

# %%
ad.data.head()
# Out:
# ant            GO                      PP
# feature         x         y  or         x         y  or
# frame
# 1        0.038876  0.063685 NaN  0.038876  0.063685 NaN
# 2        0.038865  0.063683 NaN  0.038865  0.063683 NaN
# 3        0.038875  0.063679 NaN  0.038875  0.063679 NaN
# 4        0.038876  0.063675 NaN  0.038876  0.063675 NaN
# 5        0.038863  0.063664 NaN  0.038863  0.063664 NaN

# %% [markdown]
# ### Plot the trajectories of two ants, with the background image as background

# %%
fig, ax = plt.subplots(1, 1, figsize=(10 ,10))

# load the background image
bg = ex.get_bg()

# get the scale parameter to convert real world units to pixels
scale = ex.prmtrs['geometry_rscale']

# show the image
ax.imshow(bg)

# plot trajectories on image
for ant in ['PP', 'GO']:
    x = ad.data.loc[:, idx[ant, 'x']]/scale
    y = ad.data.loc[:, idx[ant, 'y']]/scale
    ax.plot(x, y, alpha=0.75)

# hide axis
ax.axis('off');

# %% [markdown]
# ### Plot the trajectories of all ants

# %%
# reload, this time with all ants
ad = axAntData(ex, movlist=[1])

# now plot (note the use the negative of y to have 
# the same axis orientation as the images)
fig, axs = plt.subplots(4, 4, figsize=(16, 16))
axs = axs.flatten()

for i, ant in enumerate(ex.antlist):
    axs[i].plot(ad.data.loc[:, idx[ant, 'x']], -ad.data.loc[:, idx[ant,'y']], 
                color='grey', linewidth=1)
    axs[i].set_xlim((0.01, 0.08))
    axs[i].set_ylim((-0.07, 0))
    axs[i].axis('off')

# %% [markdown]
# ### Calculating some measures

# %% [markdown]
# Define the nest location as the median location of all ants. This is possible as in this experiment the majority of the ants are most of the time in the nest. To account for periods where many ants leave the nest for short while, we use a median temporal filter.

# %%
# calculating proxi for nest location
ad.data[('nest', 'x')] = \
        ad.data.loc[:, idx[:, 'x']].interpolate(limit_area='inside').median(axis=1)
ad.data[('nest', 'y')] = \
        ad.data.loc[:, idx[:, 'y']].interpolate(limit_area='inside').median(axis=1)

# temporal smoothing for consistency
window = 3001 # 5 minues in frames 
ad.data[('nest', 'x')] = \
        ad.data[('nest', 'x')].rolling(window, center=True).median()
ad.data[('nest', 'y')] = \
        ad.data[('nest', 'y')].rolling(window, center=True).median()

# for each ant, add a column which is True if the ant is 
# outside the nest (distance above threshold)
thresh = 0.01 # in meters
for ant in ad.antlist:
    dx = ad.data[ant]['x'] - ad.data['nest']['x']
    dy = ad.data[ant]['y'] - ad.data['nest']['y']
    ad.data[(ant, 'dnest')] = np.sqrt(dx**2 + dy**2)
    ad.data[(ant, 'outside')] = ad.data[(ant, 'dnest')] > thresh

# %% [markdown]
#
# Plot the nest trajectory ontop of one frame from the experiment

# %%
fig, ax = plt.subplots(1, 1, figsize=(10 ,10))

# load the first frame in the movie
frame = ex.get_frame(1)

# get the scale parameter to convert real world units to pixels
scale = ex.prmtrs['geometry_rscale']

# show the image
ax.imshow(frame)

# plot nest trajectory on image
x = ad.data.loc[:,idx['nest','x']]/scale
y = ad.data.loc[:,idx['nest','y']]/scale
ax.plot(x, y, alpha=0.75, color='magenta', linewidth=3)

# hide axis
ax.axis('off');

# %% [markdown]
# Add velocity column to data table

# %%
for ant in ad.antlist:
    dx = ad.data[ant]['x'].diff()
    dy = ad.data[ant]['y'].diff()
    ad.data[(ant, 'v')] = np.sqrt(dx**2 + dy**2)

# %% [markdown]
# Plot velocity histogram when outside of the nest

# %%
fig, ax = plt.subplots(1, 1, figsize=(10,6))

for ant in ['PP', 'GO']:
    v = ad.data[ant]['v']
    v = v[ad.data[ant]['outside']]
    v = v[~np.isnan(v)]
    sns.distplot(1000*v, label=ant)

ax.set_xlim((0, 2))
ax.set_ylim((0, 5));
ax.set_xlabel('Velocity (mm/s)', fontsize=20)
ax.set_ylabel('pdf', fontsize=20)
ax.legend(fontsize=20);

# %% [markdown]
# ### Loading JAABA scores

# %% [markdown]
# This is an example of loading tracks together with JAABA classifications (in case it have some of course, see the JAABA section). We will use the A36 dataset, which comes with some JAABA classifications, see the anTraX publication for details about those.

# %%
expdir = '/Users/asaf/Box Sync/anTraX/datasets/A36'
ex = axExperiment(expdir, session='antrax')
ad = axAntData(ex, movlist=[1], antlist=['YY'])
ad.set_jaaba(behaviors=['WalkWithLarva'])
ad.data.head()
# Out:
# ant            YY
# feature        or scores_WalkWithLarva         x         y
# frame
# 1             NaN            -0.067551  0.104412  0.046353
# 2             NaN            -0.644878  0.104372  0.046459
# 3        0.984315             2.967741  0.103487  0.045808
# 4        1.083810             1.790937  0.103467  0.045851
# 5        1.248774             0.771301  0.103476  0.046042

# %%
fig, ax = plt.subplots(1, 1, figsize=(10 ,10))


# load the background image
bg = ex.get_bg()

# get the scale parameter to convert real world units to pixels
scale = ex.prmtrs['geometry_rscale']

# show the image
ax.imshow(bg)

# plot trajectories on image
x = ad.data.loc[:, idx['YY', 'x']]/scale
y = ad.data.loc[:, idx['YY', 'y']]/scale
ax.plot(x, y, alpha=0.5, color='dimgrey')

# plot the part of the trajectory classified as WalkWithLarva
ix = ad.data.loc[:, idx['YY', 'scores_WalkWithLarva']] <= 0
x[ix] = np.nan
y[ix] = np.nan

ax.plot(x, y, alpha=0.5, color='indianred', linewidth=2)

# hide axis
ax.axis('off');

# %% [markdown]
# ### Loading DeepLabCut tracking results

# %% [markdown]
# This is an example of loading tracks together with DeepLabCut pose tracking results (see the corresponding section in the documentations). We will use the A36 dataset, which comes with some DLC tracking results, see the anTraX publication for details about those. Loading DLC results might take a bit of time.

# %%
expdir = '/Users/asaf/Box Sync/anTraX/datasets/A36'
ex = axExperiment(expdir, session='antrax')
ad = axAntData(ex, movlist=[1], antlist=['YY'])
ad.set_dlc(dlcproject='ant_walk')
ad.data.head()
# Out:
# ant                  YY                                              \
# feature Head_likelihood     Head_x     Head_y L_ant_root_likelihood
# frame
# 1                   NaN        NaN        NaN                   NaN
# 2                   NaN        NaN        NaN                   NaN
# 3                   1.0  57.262295  86.771477                   1.0
# 4                   1.0  56.452419  88.234024                   1.0
# 5                   1.0  54.790932  88.055313                   1.0
#
# ant                                                                 \
# feature L_ant_root_x L_ant_root_y L_ant_tip_likelihood L_ant_tip_x
# frame
# 1                NaN          NaN                  NaN         NaN
# 2                NaN          NaN                  NaN         NaN
# 3          60.752239    86.134300                  1.0   64.610764
# 4          59.649086    87.968117                  1.0   62.740105
# 5          59.194344    87.052254                  1.0   63.489567
#
# ant                                        ...                        \
# feature L_ant_tip_y L_fore_leg_likelihood  ...     Tail_x     Tail_y
# frame                                      ...
# 1               NaN                   NaN  ...        NaN        NaN
# 2               NaN                   NaN  ...        NaN        NaN
# 3         97.347961              1.000000  ...  54.392708  20.795399
# 4         97.785744              0.998592  ...  54.154308  22.157581
# 5        102.258698              1.000000  ...  51.277115  21.141693
#
# ant                                                                        \
# feature ThxAbd_likelihood   ThxAbd_x   ThxAbd_y    bbx0    bby0        or
# frame
# 1                     NaN        NaN        NaN     NaN     NaN       NaN
# 2                     NaN        NaN        NaN     NaN     NaN       NaN
# 3                     1.0  59.600796  45.529133  2819.0  1228.0  0.984315
# 4                     1.0  59.776318  47.396057  2820.0  1229.0  1.083810
# 5                     1.0  59.186344  46.041176  2825.0  1230.0  1.248774
#
# ant
# feature         x         y
# frame
# 1        0.104412  0.046353
# 2        0.104372  0.046459
# 3        0.103487  0.045808
# 4        0.103467  0.045851
# 5        0.103476  0.046042
#
# [5 rows x 47 columns]
